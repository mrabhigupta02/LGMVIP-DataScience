# %% [markdown]
# <a href="https://colab.research.google.com/github/imabhishekgupt/LGMVIP-DataScience/blob/main/Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LGMVIP TASK-2 LEVEL** - Intermediate Decision Tree ML Project.
#
# **PREDICTION USING DECISION TREE ALGORITHM**
#
# **OBJECTIVE** - Create the decision Tree classifier and visualize if graphically, the purpose is if we feed any new data to this classifier it would be able to predict the right class accordingly
#
# **Author** :-  ABHISHEK GUPTA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Loading the data set

# %%
data = sns.load_dataset("iris")
data.head(5)# First5
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.tail(5) # First
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
data.info()# used to see the information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
str(data)# to see the structure of the data set
# Out:
# '     sepal_length  sepal_width  petal_length  petal_width    species\n0             5.1          3.5           1.4          0.2     setosa\n1             4.9          3.0           1.4          0.2     setosa\n2             4.7          3.2           1.3          0.2     setosa\n3             4.6          3.1           1.5          0.2     setosa\n4             5.0          3.6           1.4          0.2     setosa\n..            ...          ...           ...          ...        ...\n145           6.7          3.0           5.2          2.3  virginica\n146           6.3          2.5           5.0          1.9  virginica\n147           6.5          3.0           5.2          2.0  virginica\n148           6.2          3.4           5.4          2.3  virginica\n149           5.9          3.0           5.1          1.8  virginica\n\n[150 rows x 5 columns]'

# %%
X = data[['sepal_length','sepal_width','petal_length','petal_width']].values
X[0:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
Y = data['species']
Y[0:5]
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_trainset, X_testset, Y_trainset, Y_testset = train_test_splittrain_X, test_X, train_y, test_y= train_test_split(X,Y, test_size=0.3, random_state=0)

# %%
SpeciesTree = DecisionTreeClassifier(criterion = 'entropy', max_depth = 4)
SpeciesTree
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=4, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
SpeciesTree.fit(X_trainset, Y_trainset)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=4, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# ## Prediction

# %%
predTree = SpeciesTree.predict(X_testset)

# %%
print(predTree [0:5])
print(Y_testset[0:5])
# Out:
# ['virginica' 'versicolor' 'setosa' 'virginica' 'setosa']
# 114     virginica
# 62     versicolor
# 33         setosa
# 107     virginica
# 7          setosa
# Name: species, dtype: object

# %% [markdown]
# ## Evaluation

# %%
from sklearn import metrics
print("Accuracy: ",metrics.accuracy_score(Y_testset, predTree))
# Out:
# Accuracy:  0.9777777777777777

# %% [markdown]
# ## Visualization

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
fn = data.columns[1:6]
cn = data["species"].unique().tolist()
SpeciesTree.fit(X,Y)
fig, axes = plt.subplots(nrows = 1,ncols = 1, figsize = (10,10), dpi =300)
tree.plot_tree(SpeciesTree,feature_names = fn, class_names = cn, filled = True);

# %% [markdown]
# ## Predicting Species For Set Of Values
#
# > Indented block

# %%
X_new = [[6.4,2.0,1.9,0.6]]

# %%
predTree = SpeciesTree.predict(X_new)

# %%
predTree
# Out:
# array(['setosa'], dtype=object)

# %% [markdown]
# **THANK YOU SO MUCH** **LGMVIP**
